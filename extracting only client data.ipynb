# %%
import pandas as pd
df = pd.read_csv("PolarisData.csv",header = None)
df.columns=['sentiment','File','link','Transcript']

# %%
df
# Out:
#       sentiment        File  \
# 0             1  01367195-1
# 1             1  10DB0975-1
# 2             0  1399F357-1
# 3             1  1BAB0261-1
# 4             0  25996B07-1
# ...         ...         ...
# 8386          0  BF95E6D7-2
# 8387          0  D80C9FF0-2
# 8388          0  DCA3409F-2
# 8389          0  DE24B672-2
# 8390          1  DF6C677A-2
#
#                                                    link  \
# 0     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 1     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 2     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 3     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 4     https://qevalpro.ai/fileDetails/Polraris-Polar...
# ...                                                 ...
# 8386  https://qevalpro.ai/fileDetails/Polraris-Polar...
# 8387  https://qevalpro.ai/fileDetails/Polraris-Polar...
# 8388  https://qevalpro.ai/fileDetails/Polraris-Polar...
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#       sentiment        File  \
# 0             1  01367195-1
# 1             1  10DB0975-1
# 2             0  1399F357-1
# 3             1  1BAB0261-1
# 4             0  25996B07-1
# ...         ...         ...
# 8386          0  BF95E6D7-2
# 8387          0  D80C9FF0-2
# 8388          0  DCA3409F-2
# 8389          0  DE24B672-2
# 8390          1  DF6C677A-2
#
#                                                    link  \
# 0     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 1     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 2     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 3     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 4     https://qevalpro.ai/fileDetails/Polraris-Polar...
# ...                                                 ...
# 8386  https://qevalpro.ai/fileDetails/Polraris-Polar...
# 8387  https://qevalpro.ai/fileDetails/Polraris-Polar...
# 8388  https://qevalpro.ai/fileDetails/Polraris-Polar...
# ...

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
stopword = stopwords.words('english')
stopword.pop(stopword.index('against'))
stopword.pop(stopword.index('not'))
stopword.pop(stopword.index('haven\'t'))
stopword.pop(stopword.index('more'))
stopword.pop(stopword.index('most'))
stopword.pop(stopword.index('own'))
stopword.pop(stopword.index('very'))
stopword.append('\'m')
stopword.append('\'re')
stopword.append('n')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\CU696Aliasgar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\CU696Aliasgar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
from nltk.stem import WordNetLemmatizer
ps = WordNetLemmatizer()
corpus = []
for i in range(0,len(df)):
    review = re.sub('[^a-z,A-Z0-9]',' ',df['Transcript'][i])
    review = review.lower()
    review = review.split()
    review = [ps.lemmatize(word) for word in review if not word in stopword]
    review = ' '.join(review)
    df['Transcript'][i] = review
    corpus.append(review)
#corpus
# Out:
# C:\Users\CU696Aliasgar\AppData\Local\Temp\ipykernel_16492\2830033061.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Transcript'][i] = review

# %%
df['Transcript'][499]
# Out:
# 'agent name brittany nothing first last name , client u l l , agent thank gonna get postal code , client say , agent address zip code postal code , client could know mean , agent zip code postal code , client 9 6 article near loan case polaris westerly one , agent okay, case number , client 745 9409 goodwill , agent okay verify phone number email , client 160694 , agent recall outlet go , client yes, yes, service call something like think back 2020 one ranger turner ranger 52015 vin number , agent got got case already , client okay , agent took irs service , client say , agent take dealer service fix recall , client yeah, yeah, gonna gonna take dealer orange offer know come service recall whatever wanna call never find thing morning know anyways, yes, , agent okay, reason call today check know , client want sign heard one good disapprove , agent okay, said name already , client pardon , agent vehicle already shop , client yes , agent okay give one moment reach team check okay, thanks
# ...

# %%
words = []
k = 0
i = 1
for text in df['Transcript'].values:
    
    l=[]
    #print(type(text))
    words = text.split(' ')
    for w in words:
        #print(i," :",w)
        if(w == 'agent'):
                i = 0
        if(w == 'client'):
                i = 1
        if(i == 1):
                l.append(w)
    s = " ".join(l)
    df['Transcript'][k] = s
    k = k+1
# Out:
# C:\Users\CU696Aliasgar\AppData\Local\Temp\ipykernel_16492\4003314843.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Transcript'][k] = s

# %%
df['Transcript']
# Out:
# 0       client good morning, name matthew clinton toda...
# 1       client kim , client one right showing alpha 21...
# 2       client george, k c k , client 607343235 , clie...
# 3       client hello, name kia around mullen u l l e n...
# 4       client terry martin , client 417529691 , clien...
#                               ...
# 8386    client vehicle registered husband , client 541...
# 8387    client wife probably dawned , client 6020 , cl...
# 8388    client okay , client trying see disclaimer nob...
# 8389    client robert last name wilcox w l l e c , cli...
# 8390    client yeah, michael , client phone turned , c...
# Name: Transcript, Length: 8391, dtype: object

# %%
df['Transcript'][499]
# Out:
# 'client u l l , client say , client could know mean , client 9 6 article near loan case polaris westerly one , client 745 9409 goodwill , client 160694 , client yes, yes, service call something like think back 2020 one ranger turner ranger 52015 vin number , client okay , client say , client yeah, yeah, gonna gonna take dealer orange offer know come service recall whatever wanna call never find thing morning know anyways, yes, , client want sign heard one good disapprove , client pardon , client yes , client stuff , client want without date would still cover okay thank very much , client alright, thank'

# %%
df
# Out:
#       sentiment        File  \
# 0             1  01367195-1
# 1             1  10DB0975-1
# 2             0  1399F357-1
# 3             1  1BAB0261-1
# 4             0  25996B07-1
# ...         ...         ...
# 8386          0  BF95E6D7-2
# 8387          0  D80C9FF0-2
# 8388          0  DCA3409F-2
# 8389          0  DE24B672-2
# 8390          1  DF6C677A-2
#
#                                                    link  \
# 0     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 1     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 2     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 3     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 4     https://qevalpro.ai/fileDetails/Polraris-Polar...
# ...                                                 ...
# 8386  https://qevalpro.ai/fileDetails/Polraris-Polar...
# 8387  https://qevalpro.ai/fileDetails/Polraris-Polar...
# 8388  https://qevalpro.ai/fileDetails/Polraris-Polar...
# ...

# %%
data = df[df['Transcript'] == ""]

# %%
w = data.index
z = []
for q in w:
    z.append(q)
z
# Out:
# [220, 1270, 1305, 1687, 2209, 4656, 5207, 5645, 5648, 5929, 8252]

# %%
len(z)
# Out:
# 11

# %%
df1 = pd.read_csv("myDataset.csv",header = None)
df1.columns=['sentiment','File','Transcript']
df1 = df1.iloc[z]

# %%
df1['Transcript'].to_csv("only_agent.txt")

# %%
import re
from nltk.stem import WordNetLemmatizer
ps = WordNetLemmatizer()
corpus = []
for i in z:
    review = re.sub('[^a-z,A-Z0-9]',' ',df1['Transcript'][i])
    review = review.lower()
    review = review.split()
    review = [ps.lemmatize(word) for word in review if not word in stopword]
    review = ' '.join(review)
    df1['Transcript'][i] = review
    corpus.append(review)
# Out:
# C:\Users\CU696Aliasgar\AppData\Local\Temp\ipykernel_16492\1172049708.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Transcript'][i] = review

# %%
corpus
# Out:
# ['agent hello, lupe , agent thank calling separate valley refund retirement service',
# ...

# %%
words = []
k = 0
i = 1
for text in df1['Transcript'].values:
    
    l=[]
    #print(type(text))
    words = text.split(' ')
    for w in words:
        print(i," :",w)
        if(w == 'agent'):
                i = 0
        if(w == 'client'):
                i = 1
        if(i == 1):
                l.append(w)
    s = " ".join(l)
    df1['Transcript'][k] = s
    k = k+1
# Out:
# 1  : agent
# 0  : hello,
# 0  : lupe
# 0  : ,
# 0  : agent
# 0  : thank
# 0  : calling
# 0  : separate
# 0  : valley
# 0  : refund
# 0  : retirement
# 0  : service
# 0  : agent
# 0  : calling
# 0  : top
# 0  : call
# 0  : monitored
# 0  : recorded
# 0  : quality
# 0  : assurance
# 0  : may
# 0  : please
# 0  : speak
# 0  : courtney
# 0  : 10
# 0  : month
# 0  : ,
# 0  : client
# 1  : eric
# 1  : think
# 1  : missed
# 1  : ,
# 1  : agent
# 0  : well,
# 0  : duty
# 0  : station
# 0  : make
# 0  : decision
# 0  : account
# 0  : ,
# 0  : client
# 1  : certain
# 1  : ,
# 1  : agent
# 0  : sir,
# 0  : would
# 0  : like
# 0  : know
# 0  : issue
# 0  : wifi
# 0  : connection
# 0  : ,
# 0  : client
# 1  : reason
# 1  : ,
# 1  : agent
# 0  : recently
# 0  : main
# 0  : issue
# 0  : wifi
# 0  : ,
# 0  : client
# 1  : ,
# 1  : agent
# 0  : main
# 0  : issue
# 0  : wifi
# 0  : connection
# 0  : ,
# 0  : client
# 1  : issue
# 1  : ,
# 1  : agent
# 0  : well,
# 0  : sir,
# 0  : offer
# ...

# %%
df
# Out:
#       sentiment        File  \
# 0             1  01367195-1
# 1             1  10DB0975-1
# 2             0  1399F357-1
# 3             1  1BAB0261-1
# 4             0  25996B07-1
# ...         ...         ...
# 8386          0  BF95E6D7-2
# 8387          0  D80C9FF0-2
# 8388          0  DCA3409F-2
# 8389          0  DE24B672-2
# 8390          1  DF6C677A-2
#
#                                                    link  \
# 0     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 1     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 2     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 3     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 4     https://qevalpro.ai/fileDetails/Polraris-Polar...
# ...                                                 ...
# 8386  https://qevalpro.ai/fileDetails/Polraris-Polar...
# 8387  https://qevalpro.ai/fileDetails/Polraris-Polar...
# 8388  https://qevalpro.ai/fileDetails/Polraris-Polar...
# ...

# %%
for i in z:
    df['Transcript'][i] = df1['Transcript'][i]
df.iloc[z]
# Out:
# C:\Users\CU696Aliasgar\AppData\Local\Temp\ipykernel_16492\2330000656.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Transcript'][i] = df1['Transcript'][i]
#       sentiment        File  \
# 220           0  981E44E0-1
# 1270          0  4F7FAA1A-1
# 1305          1  215714E9-1
# 1687          0  3D31D4CC-1
# 2209          0  0FDA8D17-1
# 4656          1  031A6C55-1
# 5207          0  CEFFE3B3-1
# 5645          1  38DCF4CE-2
# 5648          0  86A80AAC-2
# 5929          1  A03DB981-2
# 8252          1  7FA67777-2
#
#                                                    link  \
# 220   https://qevalpro.ai/fileDetails/Polraris-Polar...
# 1270  https://qevalpro.ai/fileDetails/Polraris-Polar...
# 1305  https://qevalpro.ai/fileDetails/Polraris-Polar...
# ...

# %%
df1
# Out:
#       sentiment        File                                         Transcript
# 220           1  g22473083.  agent hello, lupe , agent thank calling separa...
# 1270          1  g22482220.  agent calling top call monitored recorded qual...
# 1305          0  g22482944.  client hello, dan u calling optimum call moist...
# 1687          0  c61275834.  client sorry, , client person called voice mai...
# 2209          0  c61279720.  agent hello hello yes, know get closer microph...
# 4656          0  c61320951.  client call forwarded automatic voice message ...
# 5207          1  g22504506.  agent hello, yes good morning , client endo va...
# 5645          0  c61332336.  client hello , agent good afternoon, sir name ...
# 5648          0  c61332355.  client hello hello, hi , agent name yolanda vo...
# 5929          0  c61333676.  agent hello hi, name angeles annoying , client...
# 8252          1  c61356890.  agent yes hello, rick russell sean calling opt...

# %%
df.drop(z,axis = 0,inplace =True)
df
# Out:
#       sentiment        File  \
# 0             1  01367195-1
# 1             1  10DB0975-1
# 2             0  1399F357-1
# 3             1  1BAB0261-1
# 4             0  25996B07-1
# ...         ...         ...
# 8386          0  BF95E6D7-2
# 8387          0  D80C9FF0-2
# 8388          0  DCA3409F-2
# 8389          0  DE24B672-2
# 8390          1  DF6C677A-2
#
#                                                    link  \
# 0     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 1     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 2     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 3     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 4     https://qevalpro.ai/fileDetails/Polraris-Polar...
# ...                                                 ...
# 8386  https://qevalpro.ai/fileDetails/Polraris-Polar...
# 8387  https://qevalpro.ai/fileDetails/Polraris-Polar...
# 8388  https://qevalpro.ai/fileDetails/Polraris-Polar...
# ...

# %%
df.to_csv("BigData_onlyclientpolaris.csv",header = False,index=False,mode = "a")

# %%
df = pd.read_csv("BigData_onlyclientpolaris.csv")
df
# Out:
#       1  01367195-1  \
# 0     1  10DB0975-1
# 1     0  1399F357-1
# 2     1  1BAB0261-1
# 3     0  25996B07-1
# 4     1  37A28029-1
# ...  ..         ...
# 8374  0  BF95E6D7-2
# 8375  0  D80C9FF0-2
# 8376  0  DCA3409F-2
# 8377  0  DE24B672-2
# 8378  1  DF6C677A-2
#
#      https://qevalpro.ai/fileDetails/Polraris-PolarisEtech/PolarisStereo/dcj4XYIB552Fqb-8OcqS/61289/01367195-119A-11ED-82EE-0282F3755A77.mp3  \
# 0     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 1     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 2     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 3     https://qevalpro.ai/fileDetails/Polraris-Polar...
# 4     https://qevalpro.ai/fileDetails/Polraris-Polar...
# ...                                                 ...
# 8374  https://qevalpro.ai/fileDetails/Polraris-Polar...
# 8375  https://qevalpro.ai/fileDetails/Polraris-Polar...
# 8376  https://qevalpro.ai/fileDetails/Polraris-Polar...
# 8377  https://qevalpro.ai/fileDetails/Polraris-Polar...
# ...

# %%
df['0'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
